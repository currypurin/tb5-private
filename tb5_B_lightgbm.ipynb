# %%
import pandas as pd
import numpy as np
import lightgbm as lgb
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score

# %%
df_train = pd.read_csv('./input/train.csv')
df_test = pd.read_csv('./input/test.csv')
df_gender_submission = pd.read_csv('./input/gender_submission.csv')

# %%
genders = {'male': 0, 'female': 1} # 辞書を作成
# Sexをgendersを用いて変換
df_train['Sex'] = df_train['Sex'].map(genders)
df_test['Sex'] = df_test['Sex'].map(genders)

# ダミー変数化
df_train = pd.get_dummies(df_train, columns=['Embarked'])
df_test = pd.get_dummies(df_test, columns = ['Embarked'])

# 不要な列の削除
df_train.drop(['PassengerId', 'Name', 'Cabin', 'Ticket'], axis=1, inplace=True)
df_test.drop(['PassengerId', 'Name', 'Cabin', 'Ticket'], axis=1, inplace=True)

# %%
df_train.head(6)
# Out:
#    Survived  Pclass  Sex   Age  SibSp  Parch     Fare  Embarked_C  Embarked_Q  \
# 0         0       3    0  22.0      1      0   7.2500           0           0
# 1         1       1    1  38.0      1      0  71.2833           1           0
# 2         1       3    1  26.0      0      0   7.9250           0           0
# 3         1       1    1  35.0      1      0  53.1000           0           0
# 4         0       3    0  35.0      0      0   8.0500           0           0
# 5         0       3    0   NaN      0      0   8.4583           0           1
#
#    Embarked_S
# 0           1
# 1           0
# 2           1
# 3           1
# 4           1
# 5           0

# %%
X_train = df_train.iloc[:,1:]
Y_train = df_train['Survived']

# %% [markdown]
# # scikit-learnを使う

# %%
# 3分割交差検証を指定し、インスタンス化
kf = KFold(n_splits=3)

score_list = []

params = {
        'objective': 'binary',
        'metric' : 'binary_error',
        'learning_rate': 0.1,
        'num_leaves' : 300,
        'random_seed' : 1
}

for train_index, test_index in kf.split(X_train, Y_train):
    X_cv_train = X_train.iloc[train_index]
    X_cv_test = X_train.iloc[test_index]
    y_cv_train = Y_train[train_index]
    y_cv_test = Y_train[test_index]

    gbm = lgb.LGBMClassifier(objective='binary',
                        num_leaves = 300,
                        learning_rate = 0.1,
                        )
    gbm.fit(X_cv_train, y_cv_train,
        eval_set = [(X_cv_test, y_cv_test)],
        early_stopping_rounds=10,)
    
    y_pred = gbm.predict(X_cv_test, num_iteration=gbm.best_iteration_)
    score_list.append(round(accuracy_score(y_cv_test,y_pred)*100,2))
    print(round(accuracy_score(y_cv_test,y_pred)*100,2))
# Out:
# [1]	valid_0's binary_logloss: 0.653228
# Training until validation scores don't improve for 10 rounds.
# [2]	valid_0's binary_logloss: 0.622056
# [3]	valid_0's binary_logloss: 0.596004
# [4]	valid_0's binary_logloss: 0.574341
# [5]	valid_0's binary_logloss: 0.556075
# [6]	valid_0's binary_logloss: 0.54093
# [7]	valid_0's binary_logloss: 0.529472
# [8]	valid_0's binary_logloss: 0.52017
# [9]	valid_0's binary_logloss: 0.51268
# [10]	valid_0's binary_logloss: 0.505685
# [11]	valid_0's binary_logloss: 0.498798
# [12]	valid_0's binary_logloss: 0.495887
# [13]	valid_0's binary_logloss: 0.491558
# [14]	valid_0's binary_logloss: 0.489382
# [15]	valid_0's binary_logloss: 0.485895
# [16]	valid_0's binary_logloss: 0.485268
# [17]	valid_0's binary_logloss: 0.483104
# [18]	valid_0's binary_logloss: 0.48329
# [19]	valid_0's binary_logloss: 0.478652
# [20]	valid_0's binary_logloss: 0.474804
# [21]	valid_0's binary_logloss: 0.472614
# [22]	valid_0's binary_logloss: 0.470293
# [23]	valid_0's binary_logloss: 0.471045
# [24]	valid_0's binary_logloss: 0.47018
# [25]	valid_0's binary_logloss: 0.470811
# [26]	valid_0's binary_logloss: 0.472064
# [27]	valid_0's binary_logloss: 0.472998
# [28]	valid_0's binary_logloss: 0.473794
# [29]	valid_0's binary_logloss: 0.47473
# [30]	valid_0's binary_logloss: 0.4765
# [31]	valid_0's binary_logloss: 0.475887
# [32]	valid_0's binary_logloss: 0.478271
# [33]	valid_0's binary_logloss: 0.479284
# [34]	valid_0's binary_logloss: 0.481912
# Early stopping, best iteration is:
# [24]	valid_0's binary_logloss: 0.47018
# 78.45
# [1]	valid_0's binary_logloss: 0.6478
# Training until validation scores don't improve for 10 rounds.
# [2]	valid_0's binary_logloss: 0.610679
# [3]	valid_0's binary_logloss: 0.57808
# [4]	valid_0's binary_logloss: 0.55103
# [5]	valid_0's binary_logloss: 0.529032
# [6]	valid_0's binary_logloss: 0.510063
# [7]	valid_0's binary_logloss: 0.49348
# [8]	valid_0's binary_logloss: 0.481453
# [9]	valid_0's binary_logloss: 0.470481
# [10]	valid_0's binary_logloss: 0.461394
# [11]	valid_0's binary_logloss: 0.453264
# [12]	valid_0's binary_logloss: 0.447731
# [13]	valid_0's binary_logloss: 0.442205
# [14]	valid_0's binary_logloss: 0.436836
# [15]	valid_0's binary_logloss: 0.433835
# [16]	valid_0's binary_logloss: 0.42975
# [17]	valid_0's binary_logloss: 0.427649
# [18]	valid_0's binary_logloss: 0.424886
# [19]	valid_0's binary_logloss: 0.423726
# [20]	valid_0's binary_logloss: 0.423196
# [21]	valid_0's binary_logloss: 0.422494
# [22]	valid_0's binary_logloss: 0.421901
# [23]	valid_0's binary_logloss: 0.421602
# [24]	valid_0's binary_logloss: 0.42405
# [25]	valid_0's binary_logloss: 0.425706
# [26]	valid_0's binary_logloss: 0.428921
# [27]	valid_0's binary_logloss: 0.428784
# [28]	valid_0's binary_logloss: 0.431943
# [29]	valid_0's binary_logloss: 0.433296
# [30]	valid_0's binary_logloss: 0.437602
# [31]	valid_0's binary_logloss: 0.437766
# [32]	valid_0's binary_logloss: 0.441646
# [33]	valid_0's binary_logloss: 0.441801
# Early stopping, best iteration is:
# [23]	valid_0's binary_logloss: 0.421602
# 82.49
# [1]	valid_0's binary_logloss: 0.647738
# Training until validation scores don't improve for 10 rounds.
# [2]	valid_0's binary_logloss: 0.610064
# [3]	valid_0's binary_logloss: 0.578873
# [4]	valid_0's binary_logloss: 0.551957
# [5]	valid_0's binary_logloss: 0.531366
# [6]	valid_0's binary_logloss: 0.512412
# [7]	valid_0's binary_logloss: 0.496758
# [8]	valid_0's binary_logloss: 0.483597
# [9]	valid_0's binary_logloss: 0.472368
# [10]	valid_0's binary_logloss: 0.460926
# [11]	valid_0's binary_logloss: 0.452824
# [12]	valid_0's binary_logloss: 0.443913
# [13]	valid_0's binary_logloss: 0.438106
# [14]	valid_0's binary_logloss: 0.431982
# [15]	valid_0's binary_logloss: 0.427192
# [16]	valid_0's binary_logloss: 0.421821
# [17]	valid_0's binary_logloss: 0.415323
# [18]	valid_0's binary_logloss: 0.411963
# [19]	valid_0's binary_logloss: 0.408831
# [20]	valid_0's binary_logloss: 0.407025
# [21]	valid_0's binary_logloss: 0.40408
# [22]	valid_0's binary_logloss: 0.402129
# [23]	valid_0's binary_logloss: 0.399916
# [24]	valid_0's binary_logloss: 0.398417
# [25]	valid_0's binary_logloss: 0.397427
# [26]	valid_0's binary_logloss: 0.395958
# [27]	valid_0's binary_logloss: 0.395623
# [28]	valid_0's binary_logloss: 0.396227
# [29]	valid_0's binary_logloss: 0.396772
# [30]	valid_0's binary_logloss: 0.395473
# [31]	valid_0's binary_logloss: 0.395664
# [32]	valid_0's binary_logloss: 0.394447
# [33]	valid_0's binary_logloss: 0.395853
# [34]	valid_0's binary_logloss: 0.395229
# [35]	valid_0's binary_logloss: 0.395019
# [36]	valid_0's binary_logloss: 0.394325
# [37]	valid_0's binary_logloss: 0.393644
# [38]	valid_0's binary_logloss: 0.394193
# [39]	valid_0's binary_logloss: 0.394001
# [40]	valid_0's binary_logloss: 0.394081
# [41]	valid_0's binary_logloss: 0.394861
# [42]	valid_0's binary_logloss: 0.394573
# [43]	valid_0's binary_logloss: 0.393202
# [44]	valid_0's binary_logloss: 0.391311
# [45]	valid_0's binary_logloss: 0.391115
# [46]	valid_0's binary_logloss: 0.391022
# [47]	valid_0's binary_logloss: 0.393361
# [48]	valid_0's binary_logloss: 0.392113
# [49]	valid_0's binary_logloss: 0.391442
# [50]	valid_0's binary_logloss: 0.392508
# [51]	valid_0's binary_logloss: 0.393506
# [52]	valid_0's binary_logloss: 0.392895
# [53]	valid_0's binary_logloss: 0.392387
# [54]	valid_0's binary_logloss: 0.393034
# [55]	valid_0's binary_logloss: 0.392915
# [56]	valid_0's binary_logloss: 0.393906
# Early stopping, best iteration is:
# [46]	valid_0's binary_logloss: 0.391022
# 84.51
# /home/hideki/anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /home/hideki/anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /home/hideki/anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:

# %%
score_list
# Out:
# [78.45, 82.49, 84.51]

# %%
gbm.get_params
# Out:
# <bound method LGBMModel.get_params of LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#         importance_type='split', learning_rate=0.1, max_depth=-1,
#         min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#         n_estimators=100, n_jobs=-1, num_leaves=300, objective='binary',
#         random_state=None, reg_alpha=0.0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0)>

# %%
df_gender_submission['Survived'] = y_pred

# %%
df_gender_submission.to_csv('lightgbm.csv',index = False)

# %% [markdown]
# # scikit-learnを使わない

# %%
X_train = df_train.iloc[:,1:]
Y_train = df_train['Survived']

# 3分割交差検証を指定し、インスタンス化
skf = KFold(n_splits=3)

params = {
        'objective': 'binary',
        'learning_rate': 0.1,
        'num_leaves' : 300
}


# skf.split(X_train.Ytrain)で、X_trainとY_trainを3分割し、交差検証をする
for train_index, test_index in skf.split(X_train, Y_train):
    X_cv_train = X_train.iloc[train_index]
    X_cv_test = X_train.iloc[test_index]
    y_cv_train = Y_train[train_index]
    y_cv_test = Y_train[test_index]
    
    lgb_train = lgb.Dataset(X_cv_train,y_cv_train)
    lgb_eval = lgb.Dataset(X_cv_test,y_cv_test)
    
    gbm = lgb.train(params = params,
            train_set = lgb_train,
            num_boost_round=50,
            valid_sets=lgb_eval,
            early_stopping_rounds=20)
    
    y_pred = gbm.predict(X_cv_test, num_iteration=gbm.best_iteration)

    # acuuracyを表示
    preds = np.round(gbm.predict(X_cv_test))
    print(round(accuracy_score(y_cv_test,preds)*100,2))
# Out:
# [1]	valid_0's binary_logloss: 0.653228
# Training until validation scores don't improve for 20 rounds.
# [2]	valid_0's binary_logloss: 0.622056
# [3]	valid_0's binary_logloss: 0.596004
# [4]	valid_0's binary_logloss: 0.574341
# [5]	valid_0's binary_logloss: 0.556075
# [6]	valid_0's binary_logloss: 0.54093
# [7]	valid_0's binary_logloss: 0.529472
# [8]	valid_0's binary_logloss: 0.52017
# [9]	valid_0's binary_logloss: 0.51268
# [10]	valid_0's binary_logloss: 0.505685
# [11]	valid_0's binary_logloss: 0.498798
# [12]	valid_0's binary_logloss: 0.495887
# [13]	valid_0's binary_logloss: 0.491558
# [14]	valid_0's binary_logloss: 0.489382
# [15]	valid_0's binary_logloss: 0.485895
# [16]	valid_0's binary_logloss: 0.485268
# [17]	valid_0's binary_logloss: 0.483104
# [18]	valid_0's binary_logloss: 0.48329
# [19]	valid_0's binary_logloss: 0.478652
# [20]	valid_0's binary_logloss: 0.474804
# [21]	valid_0's binary_logloss: 0.472614
# [22]	valid_0's binary_logloss: 0.470293
# [23]	valid_0's binary_logloss: 0.471045
# [24]	valid_0's binary_logloss: 0.47018
# [25]	valid_0's binary_logloss: 0.470811
# [26]	valid_0's binary_logloss: 0.472064
# [27]	valid_0's binary_logloss: 0.472998
# [28]	valid_0's binary_logloss: 0.473794
# [29]	valid_0's binary_logloss: 0.47473
# [30]	valid_0's binary_logloss: 0.4765
# [31]	valid_0's binary_logloss: 0.475887
# [32]	valid_0's binary_logloss: 0.478271
# [33]	valid_0's binary_logloss: 0.479284
# [34]	valid_0's binary_logloss: 0.481912
# [35]	valid_0's binary_logloss: 0.484632
# [36]	valid_0's binary_logloss: 0.486158
# [37]	valid_0's binary_logloss: 0.489127
# [38]	valid_0's binary_logloss: 0.490886
# [39]	valid_0's binary_logloss: 0.491267
# [40]	valid_0's binary_logloss: 0.492978
# [41]	valid_0's binary_logloss: 0.494149
# [42]	valid_0's binary_logloss: 0.496385
# [43]	valid_0's binary_logloss: 0.495591
# [44]	valid_0's binary_logloss: 0.496776
# Early stopping, best iteration is:
# [24]	valid_0's binary_logloss: 0.47018
# 78.45
# [1]	valid_0's binary_logloss: 0.6478
# Training until validation scores don't improve for 20 rounds.
# [2]	valid_0's binary_logloss: 0.610679
# [3]	valid_0's binary_logloss: 0.57808
# [4]	valid_0's binary_logloss: 0.55103
# [5]	valid_0's binary_logloss: 0.529032
# [6]	valid_0's binary_logloss: 0.510063
# [7]	valid_0's binary_logloss: 0.49348
# [8]	valid_0's binary_logloss: 0.481453
# [9]	valid_0's binary_logloss: 0.470481
# [10]	valid_0's binary_logloss: 0.461394
# [11]	valid_0's binary_logloss: 0.453264
# [12]	valid_0's binary_logloss: 0.447731
# [13]	valid_0's binary_logloss: 0.442205
# [14]	valid_0's binary_logloss: 0.436836
# [15]	valid_0's binary_logloss: 0.433835
# [16]	valid_0's binary_logloss: 0.42975
# [17]	valid_0's binary_logloss: 0.427649
# [18]	valid_0's binary_logloss: 0.424886
# [19]	valid_0's binary_logloss: 0.423726
# [20]	valid_0's binary_logloss: 0.423196
# [21]	valid_0's binary_logloss: 0.422494
# [22]	valid_0's binary_logloss: 0.421901
# [23]	valid_0's binary_logloss: 0.421602
# [24]	valid_0's binary_logloss: 0.42405
# [25]	valid_0's binary_logloss: 0.425706
# [26]	valid_0's binary_logloss: 0.428921
# [27]	valid_0's binary_logloss: 0.428784
# [28]	valid_0's binary_logloss: 0.431943
# [29]	valid_0's binary_logloss: 0.433296
# [30]	valid_0's binary_logloss: 0.437602
# [31]	valid_0's binary_logloss: 0.437766
# [32]	valid_0's binary_logloss: 0.441646
# [33]	valid_0's binary_logloss: 0.441801
# [34]	valid_0's binary_logloss: 0.445793
# [35]	valid_0's binary_logloss: 0.447486
# [36]	valid_0's binary_logloss: 0.451595
# [37]	valid_0's binary_logloss: 0.454859
# [38]	valid_0's binary_logloss: 0.456332
# [39]	valid_0's binary_logloss: 0.457575
# [40]	valid_0's binary_logloss: 0.459137
# [41]	valid_0's binary_logloss: 0.461911
# [42]	valid_0's binary_logloss: 0.462802
# [43]	valid_0's binary_logloss: 0.465297
# Early stopping, best iteration is:
# [23]	valid_0's binary_logloss: 0.421602
# 82.49
# [1]	valid_0's binary_logloss: 0.647738
# Training until validation scores don't improve for 20 rounds.
# [2]	valid_0's binary_logloss: 0.610064
# [3]	valid_0's binary_logloss: 0.578873
# [4]	valid_0's binary_logloss: 0.551957
# [5]	valid_0's binary_logloss: 0.531366
# [6]	valid_0's binary_logloss: 0.512412
# [7]	valid_0's binary_logloss: 0.496758
# [8]	valid_0's binary_logloss: 0.483597
# [9]	valid_0's binary_logloss: 0.472368
# [10]	valid_0's binary_logloss: 0.460926
# [11]	valid_0's binary_logloss: 0.452824
# [12]	valid_0's binary_logloss: 0.443913
# [13]	valid_0's binary_logloss: 0.438106
# [14]	valid_0's binary_logloss: 0.431982
# [15]	valid_0's binary_logloss: 0.427192
# [16]	valid_0's binary_logloss: 0.421821
# [17]	valid_0's binary_logloss: 0.415323
# [18]	valid_0's binary_logloss: 0.411963
# [19]	valid_0's binary_logloss: 0.408831
# [20]	valid_0's binary_logloss: 0.407025
# [21]	valid_0's binary_logloss: 0.40408
# [22]	valid_0's binary_logloss: 0.402129
# [23]	valid_0's binary_logloss: 0.399916
# [24]	valid_0's binary_logloss: 0.398417
# [25]	valid_0's binary_logloss: 0.397427
# [26]	valid_0's binary_logloss: 0.395958
# [27]	valid_0's binary_logloss: 0.395623
# [28]	valid_0's binary_logloss: 0.396227
# [29]	valid_0's binary_logloss: 0.396772
# [30]	valid_0's binary_logloss: 0.395473
# [31]	valid_0's binary_logloss: 0.395664
# [32]	valid_0's binary_logloss: 0.394447
# [33]	valid_0's binary_logloss: 0.395853
# [34]	valid_0's binary_logloss: 0.395229
# [35]	valid_0's binary_logloss: 0.395019
# [36]	valid_0's binary_logloss: 0.394325
# [37]	valid_0's binary_logloss: 0.393644
# [38]	valid_0's binary_logloss: 0.394193
# [39]	valid_0's binary_logloss: 0.394001
# [40]	valid_0's binary_logloss: 0.394081
# [41]	valid_0's binary_logloss: 0.394861
# [42]	valid_0's binary_logloss: 0.394573
# [43]	valid_0's binary_logloss: 0.393202
# [44]	valid_0's binary_logloss: 0.391311
# [45]	valid_0's binary_logloss: 0.391115
# [46]	valid_0's binary_logloss: 0.391022
# [47]	valid_0's binary_logloss: 0.393361
# [48]	valid_0's binary_logloss: 0.392113
# [49]	valid_0's binary_logloss: 0.391442
# [50]	valid_0's binary_logloss: 0.392508
# Did not meet early stopping. Best iteration is:
# [46]	valid_0's binary_logloss: 0.391022
# 84.51
