# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import lightgbm as lgb

# %%
df_train = pd.read_csv('./input/train.csv')
df_test = pd.read_csv('./input/test.csv')
df_gender_submission = pd.read_csv('./input/gender_submission.csv')

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score

# %%
genders = {'male': 0, 'female': 1} # 辞書を作成
# Sexをgendersを用いて変換
df_train['Sex'] = df_train['Sex'].map(genders)
df_test['Sex'] = df_test['Sex'].map(genders)

# %%
# ダミー変数化
df_train = pd.get_dummies(df_train, columns=['Embarked'])
df_test = pd.get_dummies(df_test, columns = ['Embarked'])

# %%
# 不要な列の削除
df_train.drop(['PassengerId', 'Name', 'Cabin', 'Ticket'], axis=1, inplace=True)
df_test.drop(['PassengerId', 'Name', 'Cabin', 'Ticket'], axis=1, inplace=True)

# %%
df_train.head()
# Out:
#    Survived  Pclass  Sex   Age  SibSp  Parch     Fare  Embarked_C  Embarked_Q  \
# 0         0       3    0  22.0      1      0   7.2500           0           0
# 1         1       1    1  38.0      1      0  71.2833           1           0
# 2         1       3    1  26.0      0      0   7.9250           0           0
# 3         1       1    1  35.0      1      0  53.1000           0           0
# 4         0       3    0  35.0      0      0   8.0500           0           0
#
#    Embarked_S
# 0           1
# 1           0
# 2           1
# 3           1
# 4           1

# %%
X_train = df_train.iloc[:,1:]
Y_train = df_train['Survived'].values

# %%
# 3分割交差検証を指定し、インスタンス化
skf = StratifiedKFold(n_splits=3)

params = {
        'objective': 'binary',
        'learning_rate': 0.1,
        'num_leaves' : 300
}


# skf.split(X_train.Ytrain)で、X_trainとY_trainを3分割し、交差検証をする
for train_index, test_index in skf.split(X_train, Y_train):
    X_cv_train = X_train.iloc[train_index]
    X_cv_test = X_train.iloc[test_index]
    y_cv_train = Y_train[train_index]
    y_cv_test = Y_train[test_index]
    
    lgb_train = lgb.Dataset(X_cv_train,y_cv_train)
    lgb_eval = lgb.Dataset(X_cv_test,y_cv_test)
    
    gbm = lgb.train(params = params,
            train_set = lgb_train,
            num_boost_round=50,
            valid_sets=lgb_eval,
            early_stopping_rounds=20)
    
    y_pred = gbm.predict(X_cv_test, num_iteration=gbm.best_iteration)

    # acuuracyを表示
    preds = np.round(gbm.predict(X_cv_test))
    print(round(accuracy_score(y_cv_test,preds)*100,2))
# Out:
# [1]	valid_0's binary_logloss: 0.653809
# Training until validation scores don't improve for 20 rounds.
# [2]	valid_0's binary_logloss: 0.622564
# [3]	valid_0's binary_logloss: 0.597825
# [4]	valid_0's binary_logloss: 0.575612
# [5]	valid_0's binary_logloss: 0.557721
# [6]	valid_0's binary_logloss: 0.542859
# [7]	valid_0's binary_logloss: 0.531736
# [8]	valid_0's binary_logloss: 0.522472
# [9]	valid_0's binary_logloss: 0.514633
# [10]	valid_0's binary_logloss: 0.509292
# [11]	valid_0's binary_logloss: 0.504134
# [12]	valid_0's binary_logloss: 0.499229
# [13]	valid_0's binary_logloss: 0.496218
# [14]	valid_0's binary_logloss: 0.491775
# [15]	valid_0's binary_logloss: 0.490236
# [16]	valid_0's binary_logloss: 0.488807
# [17]	valid_0's binary_logloss: 0.486969
# [18]	valid_0's binary_logloss: 0.486387
# [19]	valid_0's binary_logloss: 0.482192
# [20]	valid_0's binary_logloss: 0.479107
# [21]	valid_0's binary_logloss: 0.477294
# [22]	valid_0's binary_logloss: 0.476172
# [23]	valid_0's binary_logloss: 0.475082
# [24]	valid_0's binary_logloss: 0.475496
# [25]	valid_0's binary_logloss: 0.476675
# [26]	valid_0's binary_logloss: 0.476861
# [27]	valid_0's binary_logloss: 0.478161
# [28]	valid_0's binary_logloss: 0.478659
# [29]	valid_0's binary_logloss: 0.478979
# [30]	valid_0's binary_logloss: 0.480963
# [31]	valid_0's binary_logloss: 0.483043
# [32]	valid_0's binary_logloss: 0.484591
# [33]	valid_0's binary_logloss: 0.485963
# [34]	valid_0's binary_logloss: 0.487054
# [35]	valid_0's binary_logloss: 0.490527
# [36]	valid_0's binary_logloss: 0.492951
# [37]	valid_0's binary_logloss: 0.494064
# [38]	valid_0's binary_logloss: 0.497174
# [39]	valid_0's binary_logloss: 0.498775
# [40]	valid_0's binary_logloss: 0.50052
# [41]	valid_0's binary_logloss: 0.502864
# [42]	valid_0's binary_logloss: 0.502445
# [43]	valid_0's binary_logloss: 0.505768
# Early stopping, best iteration is:
# [23]	valid_0's binary_logloss: 0.475082
# 79.46
# [1]	valid_0's binary_logloss: 0.644785
# Training until validation scores don't improve for 20 rounds.
# [2]	valid_0's binary_logloss: 0.605515
# [3]	valid_0's binary_logloss: 0.572852
# [4]	valid_0's binary_logloss: 0.547135
# [5]	valid_0's binary_logloss: 0.524287
# [6]	valid_0's binary_logloss: 0.505448
# [7]	valid_0's binary_logloss: 0.489664
# [8]	valid_0's binary_logloss: 0.476985
# [9]	valid_0's binary_logloss: 0.465265
# [10]	valid_0's binary_logloss: 0.45422
# [11]	valid_0's binary_logloss: 0.444181
# [12]	valid_0's binary_logloss: 0.437178
# [13]	valid_0's binary_logloss: 0.430373
# [14]	valid_0's binary_logloss: 0.424622
# [15]	valid_0's binary_logloss: 0.41984
# [16]	valid_0's binary_logloss: 0.415731
# [17]	valid_0's binary_logloss: 0.411923
# [18]	valid_0's binary_logloss: 0.40962
# [19]	valid_0's binary_logloss: 0.407316
# [20]	valid_0's binary_logloss: 0.40458
# [21]	valid_0's binary_logloss: 0.402611
# [22]	valid_0's binary_logloss: 0.401671
# [23]	valid_0's binary_logloss: 0.402078
# [24]	valid_0's binary_logloss: 0.401764
# [25]	valid_0's binary_logloss: 0.402087
# [26]	valid_0's binary_logloss: 0.402024
# [27]	valid_0's binary_logloss: 0.403473
# [28]	valid_0's binary_logloss: 0.404288
# [29]	valid_0's binary_logloss: 0.406109
# [30]	valid_0's binary_logloss: 0.408673
# [31]	valid_0's binary_logloss: 0.408715
# [32]	valid_0's binary_logloss: 0.410004
# [33]	valid_0's binary_logloss: 0.412336
# [34]	valid_0's binary_logloss: 0.412689
# [35]	valid_0's binary_logloss: 0.413932
# [36]	valid_0's binary_logloss: 0.414394
# [37]	valid_0's binary_logloss: 0.416628
# [38]	valid_0's binary_logloss: 0.420399
# [39]	valid_0's binary_logloss: 0.421935
# [40]	valid_0's binary_logloss: 0.425114
# [41]	valid_0's binary_logloss: 0.426877
# [42]	valid_0's binary_logloss: 0.42713
# Early stopping, best iteration is:
# [22]	valid_0's binary_logloss: 0.401671
# 83.16
# [1]	valid_0's binary_logloss: 0.648953
# Training until validation scores don't improve for 20 rounds.
# [2]	valid_0's binary_logloss: 0.611817
# [3]	valid_0's binary_logloss: 0.582606
# [4]	valid_0's binary_logloss: 0.556714
# [5]	valid_0's binary_logloss: 0.535568
# [6]	valid_0's binary_logloss: 0.517835
# [7]	valid_0's binary_logloss: 0.503472
# [8]	valid_0's binary_logloss: 0.490954
# [9]	valid_0's binary_logloss: 0.480037
# [10]	valid_0's binary_logloss: 0.470595
# [11]	valid_0's binary_logloss: 0.461386
# [12]	valid_0's binary_logloss: 0.454299
# [13]	valid_0's binary_logloss: 0.448859
# [14]	valid_0's binary_logloss: 0.442456
# [15]	valid_0's binary_logloss: 0.437455
# [16]	valid_0's binary_logloss: 0.432882
# [17]	valid_0's binary_logloss: 0.428172
# [18]	valid_0's binary_logloss: 0.424359
# [19]	valid_0's binary_logloss: 0.422152
# [20]	valid_0's binary_logloss: 0.420298
# [21]	valid_0's binary_logloss: 0.416985
# [22]	valid_0's binary_logloss: 0.419352
# [23]	valid_0's binary_logloss: 0.417097
# [24]	valid_0's binary_logloss: 0.413797
# [25]	valid_0's binary_logloss: 0.411749
# [26]	valid_0's binary_logloss: 0.412036
# [27]	valid_0's binary_logloss: 0.411295
# [28]	valid_0's binary_logloss: 0.410407
# [29]	valid_0's binary_logloss: 0.409141
# [30]	valid_0's binary_logloss: 0.409686
# [31]	valid_0's binary_logloss: 0.409216
# [32]	valid_0's binary_logloss: 0.409006
# [33]	valid_0's binary_logloss: 0.410544
# [34]	valid_0's binary_logloss: 0.409276
# [35]	valid_0's binary_logloss: 0.410614
# [36]	valid_0's binary_logloss: 0.409949
# [37]	valid_0's binary_logloss: 0.409595
# [38]	valid_0's binary_logloss: 0.409134
# [39]	valid_0's binary_logloss: 0.411945
# [40]	valid_0's binary_logloss: 0.412088
# [41]	valid_0's binary_logloss: 0.41276
# [42]	valid_0's binary_logloss: 0.411654
# [43]	valid_0's binary_logloss: 0.412336
# [44]	valid_0's binary_logloss: 0.410915
# [45]	valid_0's binary_logloss: 0.412247
# [46]	valid_0's binary_logloss: 0.413626
# [47]	valid_0's binary_logloss: 0.414333
# [48]	valid_0's binary_logloss: 0.415292
# [49]	valid_0's binary_logloss: 0.416035
# [50]	valid_0's binary_logloss: 0.415962
# Did not meet early stopping. Best iteration is:
# [32]	valid_0's binary_logloss: 0.409006
# 83.5

# %% [markdown]
# # scikit-learnを使う

# %%
# 3分割交差検証を指定し、インスタンス化
skf = StratifiedKFold(n_splits=3)

params = {
        'objective': 'binary',
        'metric' : 'binary_error',
        'learning_rate': 0.1,
        'num_leaves' : 300,
}

for train_index, test_index in skf.split(X_train, Y_train):
    X_cv_train = X_train.iloc[train_index]
    X_cv_test = X_train.iloc[test_index]
    y_cv_train = Y_train[train_index]
    y_cv_test = Y_train[test_index]

    gbm = lgb.LGBMClassifier(objective='binary',
                        num_leaves = 300,
                        learning_rate=0.1,
                        )
    gbm.fit(X_cv_train, y_cv_train,
        eval_set = [(X_cv_test, y_cv_test)],
        early_stopping_rounds=10,)
    
    y_pred = gbm.predict(X_cv_test, num_iteration=gbm.best_iteration_)
    print(gbm.best_iteration_)
    print(round(accuracy_score(y_cv_test,y_pred)*100,2))
# Out:
# [1]	valid_0's binary_logloss: 0.653809
# Training until validation scores don't improve for 10 rounds.
# [2]	valid_0's binary_logloss: 0.622564
# [3]	valid_0's binary_logloss: 0.597825
# [4]	valid_0's binary_logloss: 0.575612
# [5]	valid_0's binary_logloss: 0.557721
# [6]	valid_0's binary_logloss: 0.542859
# [7]	valid_0's binary_logloss: 0.531736
# [8]	valid_0's binary_logloss: 0.522472
# [9]	valid_0's binary_logloss: 0.514633
# [10]	valid_0's binary_logloss: 0.509292
# [11]	valid_0's binary_logloss: 0.504134
# [12]	valid_0's binary_logloss: 0.499229
# [13]	valid_0's binary_logloss: 0.496218
# [14]	valid_0's binary_logloss: 0.491775
# [15]	valid_0's binary_logloss: 0.490236
# [16]	valid_0's binary_logloss: 0.488807
# [17]	valid_0's binary_logloss: 0.486969
# [18]	valid_0's binary_logloss: 0.486387
# [19]	valid_0's binary_logloss: 0.482192
# [20]	valid_0's binary_logloss: 0.479107
# [21]	valid_0's binary_logloss: 0.477294
# [22]	valid_0's binary_logloss: 0.476172
# [23]	valid_0's binary_logloss: 0.475082
# [24]	valid_0's binary_logloss: 0.475496
# [25]	valid_0's binary_logloss: 0.476675
# [26]	valid_0's binary_logloss: 0.476861
# [27]	valid_0's binary_logloss: 0.478161
# [28]	valid_0's binary_logloss: 0.478659
# [29]	valid_0's binary_logloss: 0.478979
# [30]	valid_0's binary_logloss: 0.480963
# [31]	valid_0's binary_logloss: 0.483043
# [32]	valid_0's binary_logloss: 0.484591
# [33]	valid_0's binary_logloss: 0.485963
# Early stopping, best iteration is:
# [23]	valid_0's binary_logloss: 0.475082
# 23
# 79.46
# [1]	valid_0's binary_logloss: 0.644785
# Training until validation scores don't improve for 10 rounds.
# [2]	valid_0's binary_logloss: 0.605515
# [3]	valid_0's binary_logloss: 0.572852
# [4]	valid_0's binary_logloss: 0.547135
# [5]	valid_0's binary_logloss: 0.524287
# [6]	valid_0's binary_logloss: 0.505448
# [7]	valid_0's binary_logloss: 0.489664
# [8]	valid_0's binary_logloss: 0.476985
# [9]	valid_0's binary_logloss: 0.465265
# [10]	valid_0's binary_logloss: 0.45422
# [11]	valid_0's binary_logloss: 0.444181
# [12]	valid_0's binary_logloss: 0.437178
# [13]	valid_0's binary_logloss: 0.430373
# [14]	valid_0's binary_logloss: 0.424622
# [15]	valid_0's binary_logloss: 0.41984
# [16]	valid_0's binary_logloss: 0.415731
# [17]	valid_0's binary_logloss: 0.411923
# [18]	valid_0's binary_logloss: 0.40962
# [19]	valid_0's binary_logloss: 0.407316
# [20]	valid_0's binary_logloss: 0.40458
# [21]	valid_0's binary_logloss: 0.402611
# [22]	valid_0's binary_logloss: 0.401671
# [23]	valid_0's binary_logloss: 0.402078
# [24]	valid_0's binary_logloss: 0.401764
# [25]	valid_0's binary_logloss: 0.402087
# [26]	valid_0's binary_logloss: 0.402024
# [27]	valid_0's binary_logloss: 0.403473
# [28]	valid_0's binary_logloss: 0.404288
# [29]	valid_0's binary_logloss: 0.406109
# [30]	valid_0's binary_logloss: 0.408673
# [31]	valid_0's binary_logloss: 0.408715
# [32]	valid_0's binary_logloss: 0.410004
# Early stopping, best iteration is:
# [22]	valid_0's binary_logloss: 0.401671
# 22
# 83.16
# [1]	valid_0's binary_logloss: 0.648953
# Training until validation scores don't improve for 10 rounds.
# [2]	valid_0's binary_logloss: 0.611817
# [3]	valid_0's binary_logloss: 0.582606
# [4]	valid_0's binary_logloss: 0.556714
# [5]	valid_0's binary_logloss: 0.535568
# [6]	valid_0's binary_logloss: 0.517835
# [7]	valid_0's binary_logloss: 0.503472
# [8]	valid_0's binary_logloss: 0.490954
# [9]	valid_0's binary_logloss: 0.480037
# [10]	valid_0's binary_logloss: 0.470595
# [11]	valid_0's binary_logloss: 0.461386
# [12]	valid_0's binary_logloss: 0.454299
# [13]	valid_0's binary_logloss: 0.448859
# [14]	valid_0's binary_logloss: 0.442456
# [15]	valid_0's binary_logloss: 0.437455
# [16]	valid_0's binary_logloss: 0.432882
# [17]	valid_0's binary_logloss: 0.428172
# [18]	valid_0's binary_logloss: 0.424359
# [19]	valid_0's binary_logloss: 0.422152
# [20]	valid_0's binary_logloss: 0.420298
# [21]	valid_0's binary_logloss: 0.416985
# [22]	valid_0's binary_logloss: 0.419352
# [23]	valid_0's binary_logloss: 0.417097
# [24]	valid_0's binary_logloss: 0.413797
# [25]	valid_0's binary_logloss: 0.411749
# [26]	valid_0's binary_logloss: 0.412036
# [27]	valid_0's binary_logloss: 0.411295
# [28]	valid_0's binary_logloss: 0.410407
# [29]	valid_0's binary_logloss: 0.409141
# [30]	valid_0's binary_logloss: 0.409686
# [31]	valid_0's binary_logloss: 0.409216
# [32]	valid_0's binary_logloss: 0.409006
# [33]	valid_0's binary_logloss: 0.410544
# [34]	valid_0's binary_logloss: 0.409276
# [35]	valid_0's binary_logloss: 0.410614
# [36]	valid_0's binary_logloss: 0.409949
# [37]	valid_0's binary_logloss: 0.409595
# [38]	valid_0's binary_logloss: 0.409134
# [39]	valid_0's binary_logloss: 0.411945
# [40]	valid_0's binary_logloss: 0.412088
# [41]	valid_0's binary_logloss: 0.41276
# [42]	valid_0's binary_logloss: 0.411654
# Early stopping, best iteration is:
# [32]	valid_0's binary_logloss: 0.409006
# 32
# 83.5
# /home/hideki/anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /home/hideki/anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /home/hideki/anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
